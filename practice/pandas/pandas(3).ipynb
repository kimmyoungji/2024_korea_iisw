# %% [markdown]
# # 처음 데이터 불러올때 Tidy 데이터인지도 확인하자!

# %%
import pandas as pd

# %%
ls
# Out:
# billboard.csv       pandas(2)_re.ipynb  pew-tidy.csv        weather.txt
# crime.csv           pandas(3).ipynb     pew.txt
# pandas(2).ipynb     pandas.ipynb        tb.csv

# %%
data = pd.read_csv('./pew.txt',sep='\t')

# %%
data.loc[3,'$10-20k']
# Out:
# 617

# %%
data.set_index('religion').stack().reset_index()
# Out:
#          religion             level_1    0
# 0        Agnostic               <$10k   27
# 1        Agnostic             $10-20k   34
# 2        Agnostic             $20-30k   60
# 3        Agnostic             $30-40k   81
# 4        Agnostic             $40-50k   76
# ..            ...                 ...  ...
# 175  Unaffiliated             $50-75k  528
# 176  Unaffiliated            $75-100k  407
# 177  Unaffiliated           $100-150k  321
# 178  Unaffiliated               >150k  258
# 179  Unaffiliated  Don't know/refused  597
#
# [180 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   religion            18 non-null     object
#  1   <$10k               18 non-null     int64
#  2   $10-20k             18 non-null     int64
#  3   $20-30k             18 non-null     int64
#  4   $30-40k             18 non-null     int64
#  5   $40-50k             18 non-null     int64
#  6   $50-75k             18 non-null     int64
#  7   $75-100k            18 non-null     int64
#  8   $100-150k           18 non-null     int64
#  9   >150k               18 non-null     int64
#  10  Don't know/refused  18 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 1.7+ KB

# %%
data_melt = data.melt('religion')

# %%
data_melt
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
data_melt.groupby('religion')[['value']].mean()
# Out:
#                          value
# religion
# Agnostic                  82.6
# Atheist                   51.5
# Buddhist                  41.1
# Catholic                 805.4
# Don’t know/refused        27.2
# Evangelical Prot         947.2
# Hindu                     25.7
# Historically Black Prot  199.5
# Jehovah's Witness         21.5
# Jewish                    68.2
# Mainline Prot            747.0
# Mormon                    58.1
# Muslim                    11.6
# Orthodox                  36.3
# Other Christian           12.9
# Other Faiths              44.9
# Other World Religions      4.2
# Unaffiliated             370.7

# %%
data = pd.read_csv('./billboard.csv')

# %%
data.columns[:7]
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked'],
#       dtype='object')

# %%
data_copy = data.melt(data.columns[:7]).dropna()

# %%
data_billboard = data.melt(data.columns[:7],var_name='A', value_name='B')

# %%
data_billboard.A.str.extract('(\d+)')
# Out:
#         0
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...    ..
# 24087  76
# 24088  76
# 24089  76
# 24090  76
# 24091  76
#
# [24092 rows x 1 columns]

# %%
import re
data_billboard
data_billboard['A'] = list(map(lambda x:re.findall('^x(\d+)st\.week$',x), data_billboard['A']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 import re
#       2 data_billboard
# ----> 3 data_billboard['A'] = list(map(lambda x:re.findall('^x(\d+)st\.week$',x), data_billboard['A']))
#
# Cell In[69], line 3, in <lambda>(x)
#       1 import re
#       2 data_billboard
# ----> 3 data_billboard['A'] = list(map(lambda x:re.findall('^x(\d+)st\.week$',x), data_billboard['A']))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/re/__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# ...

# %%
data_billboard
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 24087  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 24088  2000          Smith, Will                            Freakin' It  3:58
# 24089  2000        Zombie Nation                          Kernkraft 400  3:30
# 24090  2000       Eastsidaz, The                               Got Beef  3:58
# 24091  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
Alist = list(data_billboard['A'])
data_billboard['A'] = list(map( lambda x: re.findall('^x(\d+)[a-z]+\.week$',x) , list(data_billboard['A'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 2
#       1 Alist = list(data_billboard['A'])
# ----> 2 data_billboard['A'] = list(map( lambda x: re.findall('^x(\d+)[a-z]+\.week$',x) , list(data_billboard['A'])))
#
# Cell In[102], line 2, in <lambda>(x)
#       1 Alist = list(data_billboard['A'])
# ----> 2 data_billboard['A'] = list(map( lambda x: re.findall('^x(\d+)[a-z]+\.week$',x) , list(data_billboard['A'])))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/re/__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
# ...

# %%
data_tb = pd.read_csv('./tb.csv')

# %%
data_tb.melt(['iso2','year']).dropna()
# Out:
#        iso2  year   variable  value
# 4        AD  1993     new_sp   15.0
# 5        AD  1994     new_sp   24.0
# 6        AD  1996     new_sp    8.0
# 7        AD  1997     new_sp   17.0
# 8        AD  1998     new_sp    1.0
# ...     ...   ...        ...    ...
# 120964   VU  2008  new_sp_fu    0.0
# 121038   YE  2008  new_sp_fu    0.0
# 121092   ZA  2008  new_sp_fu    0.0
# 121119   ZM  2008  new_sp_fu    0.0
# 121148   ZW  2008  new_sp_fu    0.0
#
# [38619 rows x 4 columns]

# %%
data_tb['gender'] = data_tb.variable.map(lambda x: 'U' if x=='new_sp' else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 data_tb['gender'] = data_tb.variable.map(lambda x: 'U' if x=='new_sp' else x)
#
# AttributeError: 'int' object has no attribute 'variable'

# %%
data_tb.variable.map(lambda x: 'F' if x.startswiths('new_sp_f') else 'M' if x.startsWith('new_sp_m') else 'U')
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# ...   ...   ...      ...         ...          ...          ...           ...
# 5764   ZW  2004  14581.0         NaN          NaN        187.0         833.0
# 5765   ZW  2005  13155.0         NaN          NaN        210.0         837.0
# 5766   ZW  2006  12718.0         NaN          NaN        215.0         736.0
# 5767   ZW  2007  10583.0         6.0        132.0        138.0         500.0
# 5768   ZW  2008   9830.0         NaN          NaN        127.0         614.0
#
# ...

# %%
data_weather = pd.read_csv('./weather.txt', sep='\t')

# %%
data_weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
data_weather.melt(['id', 'year','month','element'], var_name='day').dropna()
# Out:
#               id  year  month element  day  value
# 20   MX000017004  2010     12    TMAX   d1  299.0
# 21   MX000017004  2010     12    TMIN   d1  138.0
# 24   MX000017004  2010      2    TMAX   d2  273.0
# 25   MX000017004  2010      2    TMIN   d2  144.0
# 40   MX000017004  2010     11    TMAX   d2  313.0
# ..           ...   ...    ...     ...  ...    ...
# 631  MX000017004  2010      8    TMIN  d29  153.0
# 638  MX000017004  2010      1    TMAX  d30  278.0
# 639  MX000017004  2010      1    TMIN  d30  145.0
# 674  MX000017004  2010      8    TMAX  d31  254.0
# 675  MX000017004  2010      8    TMIN  d31  154.0
#
# [66 rows x 6 columns]

# %%
data_weather['day'].map(lambda x:re.find('^d\d+$',x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/2024_Korea_iisw/myvenv2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 data_weather['day'].map(lambda x:re.find('^d\d+$',x))
# ...

# %%
# stack  : 칼럼 -> 인덱스
# unstack: 인덱스 -> 칼럼

# %%
data_weather.drop(columns=['day','id','month','variable']).set_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 data_weather.drop(columns='day', axis=1)
#
# File ~/2024_Korea_iisw/myvenv2/lib/python3.11/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
# ...

# %%
# 스택 언스택은, 반보괸느 값이 있으면 안된다. 다 지워라

# %%
SCI
세상에서 가장 많이쓰는 데이터 맹글링 프로그램 = data wrangling

# %% [markdown]
# # EDA
# - 그래프를 그리냐 안그리냐
# - 하나의 칼럼을 보느냐, 두개이상 그리냐

# %%
Tabulation -> 데이터 한눈에 보여주기 -> 일부러 한눈에 보이도록 만드는 것 3가지
1)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#   Cell In[160], line 1
#     Tabulation -> 데이터 한눈에 보여주기 -> 일부러 한눈에 보이도록 만드는 것 3가지
#                ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.groupby(['sex'])[['total_bill','tip']].mean()  # aggregation 셀 하나에 여러개의 값이 들어간다.  -> R에서는 sac라고 한다.
# Out:
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/435725366.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex'])[['total_bill','tip']].mean()  # aggregation 셀 하나에 여러개의 값이 들어간다.  -> R에서는 sac라고 한다.
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
- stacked graph plot.bar(stacked)
# Out:
#   Cell In[180], line 1
#     - stacked graph plot.bar(stacked)
#               ^
# SyntaxError: invalid syntax

# %%
# groupby 삼총사 + 함수형 페러다임
tips.groupby(['sex','day'])[['tip']].std()
# Out:
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/732907012.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])[['tip']].std()
#                   tip
# sex    day
# Male   Thur  1.353734
#        Fri   1.136428
#        Sat   1.791360
#        Sun   1.271172
# Female Thur  1.109286
#        Fri   0.938862
#        Sat   1.234480
#        Sun   1.136775

# %%
for i in d:
    print(i)
# Out:
# tip

# %%
# groupby의 핵심:

# %%
# tips.groupby(['sex','day'])[['tip']].agg(['mean','std'])
tips.groupby(['sex','day'])[['tip']].aggregate(['mean','std'])  # aggregation => # tabulation
# Out:
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/1226986628.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])[['tip']].agg(['mean','std'])
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/1226986628.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])[['tip']].aggregate(['mean','std'])
#                   tip
#                  mean       std
# sex    day
# Male   Thur  2.980333  1.353734
#        Fri   2.693000  1.136428
#        Sat   3.083898  1.791360
#        Sun   3.220345  1.271172
# ...

# %%
tips.groupby(['sex','day'])[['tip']].aggregate(['mean','std']).transform(lambda x:x+1)
# Out:
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/3204402756.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])[['tip']].aggregate(['mean','std']).transform(lambda x:x+1)
#                   tip
#                  mean       std
# sex    day
# Male   Thur  3.980333  2.353734
#        Fri   3.693000  2.136428
#        Sat   4.083898  2.791360
#        Sun   4.220345  2.271172
# Female Thur  3.575625  2.109286
#        Fri   3.781111  1.938862
#        Sat   3.801786  2.234480
#        Sun   4.367222  2.136775

# %%
tips.groupby(['day','smoker'])[['tip']].aggregate(['mean','std']).transform(lambda x:x+1)
# Out:
# /var/folders/1n/x_wfn1w17ng2dw0lf7_z5klw0000gn/T/ipykernel_44293/2281103252.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['day','smoker'])[['tip']].aggregate(['mean','std']).transform(lambda x:x+1)
#                   tip
#                  mean       std
# day  smoker
# Thur Yes     4.030000  2.113491
#      No      3.673778  2.282964
# Fri  Yes     3.714000  2.077668
#      No      3.812500  1.898494
# Sat  Yes     3.875476  2.630580
#      No      4.102889  2.642088
# Sun  Yes     4.516842  2.261151
#      No      4.167895  2.224785

# %%
x = input('')  # 동적으로도 만들수 있다....!
# Out:
#  mean

# %%
# .map, .transform, .apply_map .apply

# %%
# 설명본다 
# missing data
