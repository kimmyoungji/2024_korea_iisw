# %%
a = 1

# %%
a = b = [1,2,3] # 뮤터블데이터에 대한 문제가 있다.

# %%
b[0] = 100

# %%
a
# Out:
# [100, 2, 3]

# %%
a = [1,2,3]

# %%
b = a

# %%
b[1] = 100

# %%
a
# Out:
# [1, 2, 3]

# %%
# 뮤터블 데이터 타입의 문제. 리스트 최대한 사용하지 말것.

# %%
# b = a.copy()
b = a[:] #copy 테크닉, 이것도 하면 안된다

# 복사의 종류
# 깊은 복사와 얕은 복사
# 이부분 텐서플로우, 파이토치 배울 때 배울 것이다.

# 리스트는 편하지만, 프로그래밍을 어렵게 만든다.

# %%
a[1] = 100

# %%
# 3번째 할당 방식
a, b = 1, 2 # 이건 사실 튜플이다.
# 위의 형태를 언패킹한다로 부른다.
# 언팩킹 할때는 갯수가 맞아야 한다.
# 갯수가 틀리면 unpack Error가 난다.

# %%
a, *b = 1,2,3

# %%
a, b
# Out:
# (1, [2, 3])

# %%
*a, b = 1,2,3

# %%
a ,b
# Out:
# ([1, 2], 3)

# %%
*a, = 1,2,3 # 이게 4번재 종류의 할당

# %%
a
# Out:
# [1, 2, 3]

# %%
# 빌트인 패키지 기본으로 탑재되어 있다
import builtins

# %%
# 이 패키지에 들어있는 것은 직접 임포트 하지 않아도 사용가능
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
# 파이썬은 내부에서 모든것을 관찰할 수 있다.

# %%
for i in dir(builtins):
  if 'Error' in i:
    print(i)
# Out:
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# ChildProcessError
# ConnectionAbortedError
# ConnectionError
# ConnectionRefusedError
# ConnectionResetError
# EOFError
# EnvironmentError
# FileExistsError
# FileNotFoundError
# FloatingPointError
# IOError
# ImportError
# IndentationError
# IndexError
# InterruptedError
# IsADirectoryError
# KeyError
# LookupError
# MemoryError
# ModuleNotFoundError
# NameError
# NotADirectoryError
# NotImplementedError
# OSError
# OverflowError
# PermissionError
# ProcessLookupError
# RecursionError
# ReferenceError
# RuntimeError
# SyntaxError
# SystemError
# TabError
# TimeoutError
# TypeError
# UnboundLocalError
# UnicodeDecodeError
# UnicodeEncodeError
# UnicodeError
# UnicodeTranslateError
# ValueError
# ZeroDivisionError

# %%
# 시행착오와 분석이 중요하다.

# %%
d = 1
d += 1

# %%
d
# Out:
# 2

# %%
# swap
a = 1
b = 2

a, b = b, a

print(a,b)
# Out:
# 2 1

# %%
# 할당에서 알아야할 추가 개념
# global
# nonloacal
# 사용할 수 있지만, 사용 지양하자

# 여기까지 할당에 대한 6가지 내용.

# %%
# 조건 반복 예외처리가 프로그래밍에서의 3가지 중요한 개념이고
# 그 중에서 반복이 중요하다.

# %%
# accumulator pattern | reducer (통에 공담기)
# 누적

# %%
sum = 0
for i in range(1,11):
  sum = sum + i

# %%
sum
# Out:
# 55

# %%
del sum # sum 쓰면 안된다

# %%
# 초등학교 때 가장 처음 배우는 알고리즘
sum_ = 0
for i in range(1,11):
  sum_ += i

# %%
sum_
# Out:
# 55

# %%
sum_ = []  # 뮤터블데이터만 확장 가능하다.
for i in range(1,11):
  if i%2 == 0:
    sum_.append(i)

# %%
sum_
# Out:
# [2, 4, 6, 8, 10]

# %%
# 위와 같은 패턴을 어큐뮬레이터 패턴이라고 한다.
# 위의 방식은 오래된 방식이다.

# %%
# 한개씩 뽑아내서 누적값을 구하는 것을 어큐뮬레이터 패턴이라고 한다.
sum(sum_)
# Out:
# 30

# %%
a = [1,2,0,3,4,0,'확인']

# %%
temp = []
for i in a:
  if not i:
    temp.append(i)

# %%
temp
# Out:
# [0, 0]

# %%
# 공식 문서봐라 ** 파이썬 자체 설명을 보고 이해를 해라**

# %%
all(a)
# Out:
# False

# %%
any(a)
# Out:
# True

# %%
# 메모리 레이지 테크닉 때문에 for가 좋다.
# 무한 루프를 돌려야 할때는 while이 유리하다.
# 이론상 while은 모든 for 문을 대체할 수 있다.

# %%
a = input()
# Out:
# 3

# %%
print(a,'살입니다.')
# Out:
# 3 살입니다.

# %%
# 예외 처리하기
# 꼭 기억해야할 것: 예외는 강제로 중단할 때도 쓰고, 오류가 났을 때 계속 진행하기 위해서도 쓴다,
# 1) 일부러 중단 시킬 때
# 2) 계속 실행시키기 위해 => 시스템, 웹 쪽은 정말 중요하다.

# %%
# 일부러 예외를 발생시키는 경우

# %%
a = 1

# %%
a = []
if a:
    print('존재')
else:
    print('비존재')
# Out:
# 비존재

# %%
assert a==1 #데이터분석할 때도 디버깅용으로 많이 쓴다.

# %%
assert a!=1 #반드시 어떤 값이어야 할때 꼭 assert를 박아 놓자.
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-79-cb2067bb6b8f> in <cell line: 1>()
# ----> 1 assert a!=1
#
# AssertionError:

# %%
assert
# Out:
#   Cell In[30], line 1
#     assert
#           ^
# SyntaxError: invalid syntax

# %%
# assert 를 사용하는 경우에는 unit test가 있다.

# %%
# 프로그래밍 언어 러닝 커브 -> unit test가 생산성을 높여준다

# %%
# 파이썬의 철학: EAFP : 통보, 일단 짜고 에러나면 그때 고친다. 파이썬을 느리기 때문에 LBYL방식으로
# 확인하면 속도가 더 느려지기 때문이다 그래서 예외처리가 발달하였다.

# LBYL: C언어 코딩 스타일. 돌다리도 두드리고 건넌다.
# 36개의 키워드에서 6개가 예외처리 키워드이다.

# %%
assert a==1. 'a는 1이어야 한다.'
# Out:
#   File "<ipython-input-85-68c91d0f8eed>", line 1
#     assert a==1. 'a는 1이어야 한다.'
#                  ^
# SyntaxError: invalid syntax

# %%
raise # 강제로 에러를 발생시킨다. 문제가 생기면 중단시킨다.
# 인공지능 학습 시킬 때, assert를 사용하여 값을 잘 확인해 주어야 한다.
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-87-0ad2313ea9cf> in <cell line: 1>()
# ----> 1 raise # 강제로 에러를 발생시킨다. 문제가 생기면 중단시킨다.
#       2 # 인공지능 학습 시킬 때, assert를 사용하여 값을 잘 확인해 주어야 한다.
#
# RuntimeError: No active exception to reraise

# %%
def raisetest(num):
    if num < 100:
        raise ValueError

raisetest(90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       2     if num < 100:
#       3         raise ValueError
# ----> 5 raisetest(90)
#
# Cell In[32], line 3, in raisetest(num)
#       1 def raisetest(num):
#       2     if num < 100:
# ----> 3         raise ValueError
#
# ValueError:

# %%
Error

# %%
# 파이썬의 탑재된 라이브러리 , 엄청 두껍다.

# %%
# 세상에 새로운 것을 만드는 사람이 있지만, 프로그래머는 생산성이 중요하다. 남이 만든 것을
# 잘 가져다 사용해라

# %%
# 어떤 데이터를 수집하는지도 잘 생각해야한다.

# %%
# 잘 가져다 사용하려면
# dir(), type() 잘 사용해야한다.

# %%
import sqlite3

# %%
con = sqlite3.connect(':memory:')

# %%
dir(con) # 아래 기능에 대한 설명이 공식 문서에 다 나와있다.

# %%
# 파이썬 과제 나오는 것 꼭 해라. 피드백 받아라

# %%
# 에러가 났을 때 막는 방법: try-except

# %%
a = input("숫자입력하세요")
# Out:
# 숫자입력하세요3

# %%
type(a)
# Out:
# str

# %%
b = a-3 # 코어스 지원 안함. 강제로 형변환 해야함.
# Out:
#   File "<ipython-input-102-dda258e042fc>", line 1
#     b = a-3 //코어스 지원 안함. 강제로 형변환 해야함.
#                   ^
# SyntaxError: invalid syntax

# %%
b = int(a) - 3 # 형변환되는 것이 아니라, 새로 만드는 것이다.
# int()에 대한 설명을 봐라! 제발!
# sklearn 은 중단 시키지만, tensorflow와 pytorch 는 중단이 안된다, -> 주의주의

# %%
a = input('숫자를 입력하세요')
# Out:
# 숫자를 입력하세요삼

# %%
try:
  b = int(a)
except ValueError:
  print('V') # 재입력 받고 싶은 때 무한루프를 사용한다.
else:
  print('A')
# Out:
# V

# %%
try:
    'hello' + 20
except TypeError:
    print('which error')
else:
    print('end of try except')
# Out:
# which error

# %%
while True:
    print('hello')
    temp  = input()
    if temp == '123':
        break
else:
    print('bye')
# Out:
# hello

# %%
# 정확한 입력을 받기 위해 입력을 반복할 때 무한 루프를 사용한다
# for로 이것을 구현하기 정말 어렵다.

# %%
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
while True:
  try:
    a = input('숫자를 입력하세요')
    b = int(a)
  except ValueError:
    print('V') # 재입력 받고 싶은 때 무한루프를 사용한다.
    continue
  else:
    print('A')
    break
# Out:
# 숫자를 입력하세요3
# A

# %%
# Lazy Evaluation # 프로그래밍 세계에서 '게으르다'가 좋은 말이다.
# 메모리를 효율적으로 사용할 수 있다.
# 딥러닝 할때 정말 정말 중요하다.

# %%
# assert raise break continue

# %%
# while for try if
# with는 아직 안했다.

# %%
# 내일은 함수..! 내일 부터 시작임..

# %%
# 함수를 쓰는 이유: 재사용

# %%
# 경영학과: 바퀴의 재발명. 바퀴를 재발명하지 말아라

# %%
# 재사용 > declaration / definition 함수를 정의하다 클래스를 정의하다.
# 함수
# 클래스
# 파이썬의 철학: 책임만 질수 있으면 사용해도 된다. python consulting adult
# 함수형 프로그래밍의 장점이 있다. -> 내일

# %%
# 인자 와 매개변수의 차이
# argument (인자) - 사용할 때 쓰는 말
# parameter (매개변수) - 정의할 때 쓰는 말

# %%
# 인자는 키워드 방식과 포지셔널 방식으로 나누어진다 =

# %%
def x(a):
  print(a)

# %%
x(3)
# Out:
# 3

# %%
# 기본적으로 함수는 parameter의 수와 argument의 수가 일치해야한다.

# %%
x() # TypeError: x() missing 1 required positional argument: 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-08f9d0828de0> in <cell line: 1>()
# ----> 1 x()
#
# TypeError: x() missing 1 required positional argument: 'a'

# %%
def xx(a,b):
  print(a+3*b)

# %%
xx(2,3) #포지셔널 방식 (기본이다. 그래서 에러에 나오는 것. 단점은 순서를 바꿀수 없다.)
# Out:
# 11

# %%
xx(a=2, b=3) #키워드 방식, 장점 순서를 바꿀 수 있고, 기본값을 줄 수 있다.
# Out:
# 11

# %%
def xxx()

# %%
# python은 기본적으로 function overloading을 지원하지 않는 대신에 keyword 방식 지원
# default 값은 반드시 뒤에서 부터 채운다, 나중에 많이 쓴다. 판다스

# %%
# Positoinal 방식의 단점은 무조건 다 써야한다는 것

# %%
# 키워드 방식은 필요한 것만 적을 수 있다.

# %%
# 키워드와 포지셔널의 혼용이 가능하다. 파이썬 함수의 특징이다.

# %%
# 인자 매개변수 키워드 포지셔널 디폴트 알았다 이제 확장이 일어난다.

# %%
def y(a,/,b): # / 앞에는 반드시 포지서널 방식만 올 수 있다.
  print(a,b)

# %%
len(obj=[1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-0144d2c059a3> in <cell line: 1>()
# ----> 1 len(obj=[1,2,3])
#
# TypeError: len() takes no keyword arguments

# %%
# 파이썬은 C언어로 만들어졌고, C언어는 포지셔널 방식만 사용할 수 있다. 그래서 / 가 필요하다

# %%
def z(a,*,b): # 별표 뒤에는 반드시 키워드 방식만 사용해야 한다.
  print(a,b)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist([1,2,31,3,123,3,4], color='pink')
# Out:
# (array([5., 0., 1., 0., 0., 0., 0., 0., 0., 1.]),
#  array([  1. ,  13.2,  25.4,  37.6,  49.8,  62. ,  74.2,  86.4,  98.6,
#         110.8, 123. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 정리
#
# 함수의 인자와 매개변수가 있고
# --
# 인자과 매개변수를 받는 방식은 아래 두가지
# - 포지셔널 방식
# - 키워드 방식
# ---
# - 포지셔널은 / 앞에
# - 키워드 는 * 뒤에
# ---
# - 디폴트는 뒤에서 부터

# %%
def zz(*a):
  print(a)

# %%
zz()
# Out:
# ()

# %%
zz(a=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-eaa7967ce302> in <cell line: 1>()
# ----> 1 zz(a=1)
#
# TypeError: zz() got an unexpected keyword argument 'a'

# %%
zz(1,2,3) # 자유로운 입력을 받을 때 정말 유용하다. 우아한 방식
# 이를 가변 포지셔널 방식이라고 한다.
# Out:
# (1, 2, 3)

# %%
def zzz(**a): # 가변키워드 방식. 이게 제일 어렵다. --> 파이썬의 꽃이다. 짱중요
  print(a)

# %%
zzz() # 결과로 딕셔너리나 반환
# Out:
# {}

# %%
zz() # 결과로 튜플이 반환
# Out:
# ()

# %%
# 포지셔널, 키워드, 포지셔널 온리, 키워드 온리, 포지셔널 가변, 키워드 가변, 혼용
# 이것을 잘 알고 있으면 남의 것을 가져다 쓰기 정말 좋다.

# %%
# 키워드 포지셔널 혼용 안되는 경우

# %%
# 파이썬 함수에서 한번 키워드 방식을 쓰기 시작하면 끝가지 키워드 방식을 사용해야한다.
def xxx(a,b=3):
  print(a,b*3)

# %%
int(self, / , *args, **kwargs) # 파이썬은 이 방식을 정말 중요하다
int([x]) -> integer # 여기서 대괄호는 생략해도 된다는 의미
# Out:
#   File "<ipython-input-156-0c8a3d3b21be>", line 1
#     int(self, / , *args, **kwargs) # 파이썬은 이 방식을 정말 중요하다
#               ^
# SyntaxError: invalid syntax

# %%
def xxxx(a,/,c,*,d,**e):
    print(a,c,d,e)

# %%
xxxx(1,c=2,d=3,e=4,f=5,g=6)
# Out:
# 1 2 3 {'e': 4, 'f': 5, 'g': 6}

# %%
a = [1,2,3]

# %%
print(*a)
# Out:
# 1 2 3

# %%
b = {'key1':1,'key2':2, 'key3':3} 
a,*c = b

# %%
type(b)
# Out:
# dict

# %%
print(a,c)
# Out:
# key1 ['key2', 'key3']

# %%
# 공식문서
# 설명
# 직접 해봐라
# 익숙해지려면 2년 정도 걸린다.
# 7가지를  조합하는 것을 배울 것이다.

# %%
# 여기 가지 정의와 사용하는 방법
# 매개변수에 따라 인자를 맞춰주어야한다
# 별표가 미친다.. ?

# %%
# 미친 예시
def t(*a):
  print(a)

# %%
xx = [1,2,3,4]

# %%
t(xx)
# Out:
# ([1, 2, 3, 4],)

# %%
t(*xx) # 언팩킹 아규먼트에서 별포는 언팩킹
# Out:
# (1, 2, 3, 4)

# %%
def tt(**a):
  print(a)

# %%
xxx = {'a':1, 'b':2}

# %%
tt(**xxx)
# Out:
# {'a': 1, 'b': 2}

# %%
def t(*a):
  print(a)

# %%
t(*xxx) #키만 들어감
# Out:
# ('a', 'b')

# %%
a = {'a':1, 'b':2}
c = {'b':3, 'c':4}

# %%
b = {**a, **c}

# %%
q,*w = (1,2,3,4)
print(q,w)
# Out:
# 1 [2, 3, 4]

# %%
set1 = {1,2,3,4}
set2 = {1,2,7,8}
set3 = {**set1, **set2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 set1 = {1,2,3,4}
#       2 set2 = {1,2,7,8}
# ----> 3 set3 = {**set1, **set2}
#
# TypeError: 'set' object is not a mapping

# %%
# 별표 잘 정리하자

# %%
a = 1 # 왜 변수라고 하지 않는가?

# %%
t
# Out:
# <function __main__.t(*a)>

# %%
a = t

# %%
a
# Out:
# <function __main__.t(*a)>

# %%
aa = print

# %%
aa('문근영')
# Out:
# 문근영

# %%
# 세상에 모든 것에 이름을 붙일 수 있다.
# 그렇기 때문에 a = 1에서 a는 변수가 아니라 식별자, 이름이다. 함수도 이름을 지을 수 있다.
# 프로그래밍 관점에서는 변수이지만, 파이썬 관점에서는 이름이다.

# %%
출력하다 = print

# %%
출력하다('ㅋ')
# Out:
# ㅋ

# %%
# 그런데, 본체는 바뀌면 안된다. 본체를 물어볼 수있다.
출력하다.__qualname__ # 이런 기술을 얼라이싱 별칭을 붙인다고 말한다.
# Out:
# 'print'

# %%
# 그리고 거꾸로도 된다. 이것 때문에 디버깅이 힘들다. 조심해야한다.
print = 1

# %%
print
# Out:
# 1

# %%
# 파이썬의 함수는 x 하나다. (개중요)

# %%
def x(a):
  print(a)

# %%
x # x 자체가 함수다. 괄호는 연산자이다. 괄호는 연산자이다. 괄호는 연산자이다.
# Out:
# <function __main__.x(a)>

# %%
# ()는 callable

# %%
x
# Out:
# <function __main__.x(a)>

# %%
def q(a,/,b,c):
  print(a,b,c)

# %%
q(1,b=2)
# Out:
# 1 2

# %%
q(1,2)
# Out:
# 1 2

# %%
q(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cfc37feb3434> in <cell line: 1>()
# ----> 1 q(1,2,3)
#
# TypeError: q() takes 2 positional arguments but 3 were given

# %%
q(1,2,c=3)
# Out:
# 1 2 3

# %%
def w(a,b,/,*c,d=2):
  print(a,b,c,d)

# %%
w(2,3,1,d=4)
# Out:
# 2 3 (1,) 4

# %%
def ee(**d=3):
  print(d)
# Out:
#   File "<ipython-input-42-3e4347c8f6c0>", line 1
#     def ee(**d=3):
#               ^
# SyntaxError: invalid syntax

# %%
def rr(a,b=2,*,c,d):
  print(a,b,c,d)

# %%
rr(1,4,c=5,d=5)
# Out:
# 1 4 5 5

# %%
def yy(a,b=2,*,c,d):
  print(a,b,c,d)

# %%
yy(10,c=3,d=3)
# Out:
# 10 2 3 3

# %%
yy(a=11,c=3,d=3)
# Out:
# 11 2 3 3

# %%
def ii(a,b,c):
  print(a,b,c)

# %%
ii(1,c=2,b=10)
# Out:
# 1 10 2

# %%
def jj(a=1, b=3, c=10):
  print(a,b,c)

# %%
jj(4,14,24)
# Out:
# 4 14 24

# %%
def ss(a,b,/,d,*c,e=1,**f):
    print(a,b,d,c,e,f)

# %%
ss(1,2,3,4,5,3,e=12,f=13,g=14)
# Out:
# 1 2 3 (4, 5, 3) 12 {'f': 13, 'g': 14}

# %%
dir(builtin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-1a2d75e487de> in <cell line: 1>()
# ----> 1 dir(builtin)
#
# NameError: name 'builtin' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
