# %%
#import matplotlib.pylab as p  # 글로벌에 불필요한 변수들이 너무 많이 생긴다.
import seaborn as sns
import matplotlib.pyplot as plt # 버전2에서는 pyplot으로 사용하면 위의 상황을 예방할 수 있다.
                                # *는 가능한 사용하지 말것

# %%
tips = sns.load_dataset('tips')

# %%
sns.lineplot(tips)
# Out:
# <Axes: >
