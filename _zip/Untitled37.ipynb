# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/user/Downloads/seoul.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6324\2124392064.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:/Users/user/Downloads/seoul.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489872 entries, 0 to 489871
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     489872 non-null  object
#  1   상호명        489872 non-null  object
#  2   지점명        9898 non-null    object
#  3   상권업종대분류코드  489872 non-null  object
#  4   상권업종대분류명   489872 non-null  object
#  5   상권업종중분류코드  489872 non-null  object
#  6   상권업종중분류명   489872 non-null  object
#  7   상권업종소분류코드  489872 non-null  object
#  8   상권업종소분류명   489872 non-null  object
#  9   표준산업분류코드   489778 non-null  object
#  10  표준산업분류명    489778 non-null  object
#  11  시도코드       489872 non-null  int64
#  12  시도명        489872 non-null  object
#  13  시군구코드      489872 non-null  int64
#  14  시군구명       489872 non-null  object
#  15  행정동코드      489872 non-null  int64
#  16  행정동명       489872 non-null  object
#  17  법정동코드      489872 non-null  int64
#  18  법정동명       489872 non-null  object
# ...

# %%
data.dtypes
# Out:
# 상가업소번호        object
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드           int64
# 시도명           object
# 시군구코드          int64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드          int64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지        float64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호          int64
# 신우편번호          int64
# 동정보          float64
# 층정보           object
# 호정보          float64
# 경도           float64
# 위도           float64
# dtype: object

# %%
data.sample() # data.tail() # data.head()
# Out:
#                       상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 483804  MA010120220803559280  구주여행사  NaN        N1  시설관리·임대      N105
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 483804   여행사·보조    N10501      여행사   N75210  ...  1154510100104930000015625
#
#               건물명               도로명주소   구우편번호 신우편번호  동정보  층정보  호정보  \
# 483804  대륭테크노타운5차  서울특별시 금천구 서부샛길 632  153774  8504  NaN  NaN  NaN
#
#                 경도         위도
# 483804  126.876252  37.480515
#
# [1 rows x 39 columns]

# %% [markdown]
# # indexing / slicing

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
data.상호명
# Out:
# 0             토끼정
# 1             카페숲
# 2             다이앤
# 3            숯불에닭
# 4          맑은에스테틱
#            ...
# 489867     모아모아세탁
# 489868    지에스25강동
# 489869        런베이
# 489870        북카페
# 489871     봉구비어난곡
# Name: 상호명, Length: 489872, dtype: object

# %%
data.select_dtypes(['object','float64'])
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220805430767      토끼정  NaN        I2       음식      I201
# 1       MA010120220805430763      카페숲  NaN        I2       음식      I212
# 2       MA010120220805430969      다이앤  NaN        G2       소매      G209
# 3       MA010120220805431023     숯불에닭  NaN        I2       음식      I201
# 4       MA010120220805431191   맑은에스테틱  NaN        S2    수리·개인      S208
# ...                      ...      ...  ...       ...      ...       ...
# 489867  MA010120220804254954   모아모아세탁  NaN        S2    수리·개인      S209
# 489868  MA010120220808716142  지에스25강동  NaN        G2       소매      G204
# 489869  MA010120220806734217      런베이  NaN        S2    수리·개인      S203
# 489870  MA010120220806779253      북카페  NaN        I2       음식      I212
# 489871  MA010120220809735562   봉구비어난곡  NaN        I2       음식      I211
#
#            상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  건물본번지 건물부번지  \
# ...

# %%
data[(data['상권업종대분류명'] != '음식')|(data['상권업종소분류명']=='카페')]
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 1       MA010120220805430763      카페숲  NaN        I2       음식      I212
# 2       MA010120220805430969      다이앤  NaN        G2       소매      G209
# 4       MA010120220805431191   맑은에스테틱  NaN        S2    수리·개인      S208
# 6       MA010120220805431833      송금당  NaN        G2       소매      G217
# 7       MA010120220805432185     한스31  NaN        G2       소매      G209
# ...                      ...      ...  ...       ...      ...       ...
# 489863  MA010120220800434291  씨유대림우성점  NaN        G2       소매      G204
# 489867  MA010120220804254954   모아모아세탁  NaN        S2    수리·개인      S209
# 489868  MA010120220808716142  지에스25강동  NaN        G2       소매      G204
# 489869  MA010120220806734217      런베이  NaN        S2    수리·개인      S203
# 489870  MA010120220806779253      북카페  NaN        I2       음식      I212
#
#            상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.iloc[3:10].iloc[1:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
iris.at[3,'sepal_width']
# Out:
# 3.1

# %%
iris.iat[3,3] = 1
# Out:
# 0.2

# %%
iris.iloc[3:10,1:3] = 1

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          1.0           1.0          0.2     setosa
# 4             5.0          1.0           1.0          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tips = sns.load_dataset('tips')

# %%
tips.size
# Out:
# 1708
